# %% [markdown]
# <a href="https://colab.research.google.com/github/RenaIshida/code_sample/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 新しいセクション

# %%
# !unzip /content/drive/MyDrive/DNN_code_colab_ver200425.zip
# Out:
# Archive:  /content/drive/MyDrive/DNN_code_colab_ver200425.zip
#   inflating: DNN_code_colab_ver200425/requirements.txt
#   inflating: DNN_code_colab_ver200425/example/iris.ipynb
#   inflating: DNN_code_colab_ver200425/example/tf_gate.ipynb
#   inflating: DNN_code_colab_ver200425/example/tf_iris.ipynb
#   inflating: DNN_code_colab_ver200425/example/tf_iris.py
#   inflating: DNN_code_colab_ver200425/lesson_1/1_1_forward_propagation_after.py
#   inflating: DNN_code_colab_ver200425/lesson_1/1_1_forward_propagation.py
#   inflating: DNN_code_colab_ver200425/lesson_1/1_2_back_propagation.ipynb
#   inflating: DNN_code_colab_ver200425/lesson_1/1_4_1_mnist_sample.py
#   inflating: DNN_code_colab_ver200425/lesson_1/1_4_1_mnist_sample.txt
#   inflating: DNN_code_colab_ver200425/lesson_1/1_3_stochastic_gradient_descent.py
#   inflating: DNN_code_colab_ver200425/lesson_1/1_4_1_mnist_sample.ipynb
#   inflating: DNN_code_colab_ver200425/lesson_1/1_1_forward_propagation.ipynb
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
